# %% [markdown]
# # Introducing CNNS with TensorFlow
#
#
# In this notebook, we're going to see how we can use ```TensorFlow``` to build convolutional neural networks to work with colour image data.

# %% [markdown]
# ## Load libraries

# %%
# data tools
import os
import numpy as np
import matplotlib.pyplot as plt

# sklearn tools
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

# tf tools
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     MaxPooling2D, 
                                     Activation, 
                                     Flatten, 
                                     Dense)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
# Out:
# 2023-04-12 15:20:31.972085: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# __Define plotting function__

# %%
def plot_history(H, epochs):
    plt.style.use("seaborn-colorblind")

    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss", linestyle=":")
    plt.title("Loss curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(np.arange(0, epochs), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc", linestyle=":")
    plt.title("Accuracy curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# __Load cifar10 data__

# %% [markdown]
# We first want to load the ```cifar-10``` dataset, normalize the values, and then binarize the labels.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 11s 0us/step

# %% [markdown]
# **Question:** As an experiment, see what happens if you try to train the model with un-scaled images. Does it affect performance?

# %%
X_train = X_train/255
X_test = X_test/255

# %%
# create one-hot encodings
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %% [markdown]
# We'll also manually create a list of labels for when we come to print the classification report later.

# %%
# initialize label names for CIFAR-10 dataset
label_names = ["airplane", "automobile", 
              "bird", "cat", 
              "deer", "dog", 
              "frog", "horse", 
              "ship", "truck"]

# %% [markdown]
# ## ShallowNet

# %% [markdown]
# We're going to begin by creating one of the simplest CNN architectures with only a single convolutional layer. This type of architecture is known as the ShallowNet architecture:
# >INPUT => CONV => ReLU => FC
#
# (FC = fully connected)

# %%
#initalise model
model = Sequential()

# define CONV => ReLU
model.add(Conv2D(32, # "filter" size == number of kernels
                (3,3), # kernel size (3,3)
                padding = "same", 
                input_shape = (32, 32, 3))) # input shape (CIFAR image is 32x32x3)
model.add(Activation("relu")) #add actication function

# NB! No pooling here

# FC classifier
model.add(Flatten()) # we are flattening the convolved values == they become dense image embeddings
model.add(Dense(128)) # size of first hidden layer (dense = fully connected)
model.add(Activation("relu"))
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %% [markdown]
# We then compile our model using some of the same arguments we've already seen in different contexts.

# %%
sgd = SGD(learning_rate =.001) # stochastic gradient descent
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 4,196,618
# Trainable params: 4,196,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Plot model__

# %%
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# __Train model__

# %% [markdown]
# Finally, we train the model on the data and get our predictions.

# %%
H = model.fit(X_train, 
              y_train,
              validation_split=0.1,
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 101s 71ms/step - loss: 2.0493 - accuracy: 0.2683 - val_loss: 1.9335 - val_accuracy: 0.3266
# Epoch 2/20
# 1407/1407 [==============================] - 97s 69ms/step - loss: 1.8610 - accuracy: 0.3479 - val_loss: 1.8458 - val_accuracy: 0.3480
# Epoch 3/20
# 1407/1407 [==============================] - 99s 70ms/step - loss: 1.7876 - accuracy: 0.3766 - val_loss: 1.8063 - val_accuracy: 0.3590
# Epoch 4/20
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.7312 - accuracy: 0.3963 - val_loss: 1.7474 - val_accuracy: 0.3802
# Epoch 5/20
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.6848 - accuracy: 0.4139 - val_loss: 1.6872 - val_accuracy: 0.4138
# Epoch 6/20
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.6442 - accuracy: 0.4262 - val_loss: 1.6634 - val_accuracy: 0.4260
# Epoch 7/20
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.6099 - accuracy: 0.4378 - val_loss: 1.6562 - val_accuracy: 0.4108
# Epoch 8/20
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.5790 - accuracy: 0.4482 - val_loss: 1.6671 - val_accuracy: 0.4156
# Epoch 9/20
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.5498 - accuracy: 0.4579 - val_loss: 1.5706 - val_accuracy: 0.4546
# Epoch 10/20
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.5228 - accuracy: 0.4675 - val_loss: 1.5432 - val_accuracy: 0.4680
# Epoch 11/20
# 1407/1407 [==============================] - 102s 72ms/step - loss: 1.4993 - accuracy: 0.4759 - val_loss: 1.5612 - val_accuracy: 0.4428
# Epoch 12/20
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.4755 - accuracy: 0.4836 - val_loss: 1.5361 - val_accuracy: 0.4470
# Epoch 13/20
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.4542 - accuracy: 0.4891 - val_loss: 1.4770 - val_accuracy: 0.4830
# Epoch 14/20
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.4330 - accuracy: 0.4960 - val_loss: 1.4674 - val_accuracy: 0.4822
# Epoch 15/20
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.4119 - accuracy: 0.5052 - val_loss: 1.4433 - val_accuracy: 0.5034
# Epoch 16/20
# 1407/1407 [==============================] - 102s 72ms/step - loss: 1.3935 - accuracy: 0.5100 - val_loss: 1.4210 - val_accuracy: 0.5050
# Epoch 17/20
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.3762 - accuracy: 0.5173 - val_loss: 1.4666 - val_accuracy: 0.4844
# Epoch 18/20
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.3581 - accuracy: 0.5227 - val_loss: 1.4107 - val_accuracy: 0.4982
# Epoch 19/20
# 1407/1407 [==============================] - 101s 72ms/step - loss: 1.3411 - accuracy: 0.5284 - val_loss: 1.4054 - val_accuracy: 0.5086
# Epoch 20/20
# 1407/1407 [==============================] - 100s 71ms/step - loss: 1.3251 - accuracy: 0.5330 - val_loss: 1.3762 - val_accuracy: 0.5150

# %% [markdown]
# __Evaluate model__

# %%
predictions = model.predict(X_test, batch_size=32)
# Out:
# 313/313 [==============================] - 6s 19ms/step

# %%
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.64      0.50      0.56      1000
#   automobile       0.65      0.62      0.64      1000
#         bird       0.53      0.16      0.24      1000
#          cat       0.39      0.32      0.35      1000
#         deer       0.36      0.61      0.45      1000
#          dog       0.45      0.38      0.41      1000
#         frog       0.56      0.53      0.54      1000
#        horse       0.49      0.66      0.56      1000
#         ship       0.54      0.74      0.62      1000
#        truck       0.60      0.56      0.58      1000
#
#     accuracy                           0.51     10000
#    macro avg       0.52      0.51      0.50     10000
# weighted avg       0.52      0.51      0.50     10000

# %% [markdown]
# We can also use the ```plot_history()``` function available from ```TensorFlow``` to see how our model performs during training.
#
# These plots can tell us *a lot* about whether a model is under- or over-fiting the data. You read more at [this fantastic blog post](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Other useful blogs are [here](https://rstudio-conf-2020.github.io/dl-keras-tf/notebooks/learning-curve-diagnostics.nb.html) and there's a good video overview [here](https://youtu.be/p3CcfIjycBA).

# %%
plot_history(H, 20)
# Out:
# /tmp/ipykernel_590/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %% [markdown]
# ## LeNet

# %% [markdown]
# Next, we'll look at a slightly more complicated CNN architecture, known as ```LeNet``` after its creator Yann LeCun, who is now Chief AI Scientist at Meta. You can read more [here](https://en.wikipedia.org/wiki/LeNet).
# >INPUT => CONV => ReLU => MAXPOOL => CONV => ReLU => MAXPOOL => FC => ReLU => FC

# %% [markdown]
# __Define model__

# %%
# define model
model = Sequential()

# first set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(32, (3,3), # number of kernels to be learned, kernel size
                 padding="same", # padding = if kernel oversteps image size, use same number as the one next to it as padding
                 input_shape=(32,32,3))) # shape of the input images
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2), # using max-pooling to compress the feature space
                       strides = (2,2))) # stride of 2 left-right, and stride of 2 down

# second set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(50, (5,5),
                 padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# FC => RELU
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

# softmax classifier
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %%
sgd = SGD(learning_rate=0.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_3 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 50)        40050
#
#  activation_4 (Activation)   (None, 16, 16, 50)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 50)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3200)              0
#
#  dense_2 (Dense)             (None, 128)               409728
#
#  activation_5 (Activation)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_6 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 451,964
# Trainable params: 451,964
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Train model__

# %%
# train model
H = model.fit(X_train, 
              y_train, 
              validation_split=0.1, 
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 2.2568 - accuracy: 0.1602 - val_loss: 2.1934 - val_accuracy: 0.2202
# Epoch 2/20
# 1407/1407 [==============================] - 157s 112ms/step - loss: 2.0978 - accuracy: 0.2523 - val_loss: 2.0358 - val_accuracy: 0.2404
# Epoch 3/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.9587 - accuracy: 0.3049 - val_loss: 1.9264 - val_accuracy: 0.3106
# Epoch 4/20
# 1407/1407 [==============================] - 159s 113ms/step - loss: 1.8780 - accuracy: 0.3406 - val_loss: 1.8531 - val_accuracy: 0.3526
# Epoch 5/20
# 1407/1407 [==============================] - 157s 112ms/step - loss: 1.8054 - accuracy: 0.3694 - val_loss: 1.8125 - val_accuracy: 0.3628
# Epoch 6/20
# 1407/1407 [==============================] - 157s 112ms/step - loss: 1.7390 - accuracy: 0.3939 - val_loss: 1.7321 - val_accuracy: 0.3844
# Epoch 7/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.6801 - accuracy: 0.4090 - val_loss: 1.7388 - val_accuracy: 0.3848
# Epoch 8/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.6283 - accuracy: 0.4276 - val_loss: 1.6165 - val_accuracy: 0.4176
# Epoch 9/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.5833 - accuracy: 0.4403 - val_loss: 1.5904 - val_accuracy: 0.4342
# Epoch 10/20
# 1407/1407 [==============================] - 158s 113ms/step - loss: 1.5432 - accuracy: 0.4503 - val_loss: 1.5715 - val_accuracy: 0.4290
# Epoch 11/20
# 1407/1407 [==============================] - 158s 113ms/step - loss: 1.5066 - accuracy: 0.4657 - val_loss: 1.5036 - val_accuracy: 0.4494
# Epoch 12/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.4756 - accuracy: 0.4750 - val_loss: 1.5143 - val_accuracy: 0.4482
# Epoch 13/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.4484 - accuracy: 0.4850 - val_loss: 1.5527 - val_accuracy: 0.4520
# Epoch 14/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.4250 - accuracy: 0.4937 - val_loss: 1.4837 - val_accuracy: 0.4532
# Epoch 15/20
# 1407/1407 [==============================] - 159s 113ms/step - loss: 1.4031 - accuracy: 0.5015 - val_loss: 1.6102 - val_accuracy: 0.4356
# Epoch 16/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.3835 - accuracy: 0.5090 - val_loss: 1.3978 - val_accuracy: 0.5056
# Epoch 17/20
# 1407/1407 [==============================] - 159s 113ms/step - loss: 1.3655 - accuracy: 0.5158 - val_loss: 1.4299 - val_accuracy: 0.4908
# Epoch 18/20
# 1407/1407 [==============================] - 159s 113ms/step - loss: 1.3490 - accuracy: 0.5223 - val_loss: 1.3521 - val_accuracy: 0.5230
# Epoch 19/20
# 1407/1407 [==============================] - 158s 112ms/step - loss: 1.3309 - accuracy: 0.5286 - val_loss: 1.3744 - val_accuracy: 0.5036
# Epoch 20/20
# 1407/1407 [==============================] - 159s 113ms/step - loss: 1.3157 - accuracy: 0.5348 - val_loss: 1.3561 - val_accuracy: 0.5218

# %%
plot_history(H,20)
# Out:
# /tmp/ipykernel_590/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %%
predictions = model.predict(X_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
# 313/313 [==============================] - 9s 28ms/step
#               precision    recall  f1-score   support
#
#     airplane       0.56      0.62      0.59      1000
#   automobile       0.54      0.74      0.62      1000
#         bird       0.56      0.19      0.28      1000
#          cat       0.47      0.14      0.22      1000
#         deer       0.47      0.42      0.45      1000
#          dog       0.42      0.57      0.48      1000
#         frog       0.49      0.73      0.59      1000
#        horse       0.61      0.52      0.56      1000
#         ship       0.64      0.62      0.63      1000
#        truck       0.48      0.63      0.54      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.52      0.52      0.50     10000
# weighted avg       0.52      0.52      0.50     10000
